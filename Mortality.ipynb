# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Dell'

# %%
os.chdir("C:/Users/Dell/Desktop/data set")

# %%
import os 
os.getcwd()
# Out:
# 'C:\\Users\\Dell\\Desktop\\data set'

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data2=pd.read_csv("Mortality.csv")
data2
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3020: DtypeWarning: Columns (77) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#              id      id.1    m_id  client_m_id    hl_id  house_no  \
# 0      165767.0  165767.0    10.0          NaN      NaN     132.0
# 1      167609.0  167609.0     4.0          NaN      NaN     111.0
# 2      530767.0  530767.0   954.0          NaN  25345.0      19.0
# 3      530775.0  530775.0   962.0          NaN  25535.0      72.0
# 4      167601.0  167601.0    26.0          NaN      NaN     248.0
# 5      167593.0  167593.0     7.0          NaN      NaN      77.0
# 6      167585.0  167585.0    12.0          NaN      NaN     114.0
# 7      530751.0  530751.0   938.0          NaN  25094.0     339.0
# 8      530759.0  530759.0   946.0          NaN  25218.0     413.0
# ...

# %%
data2.head()
# Out:
#          id      id.1   m_id  client_m_id    hl_id  house_no  house_hold_no  \
# 0  165767.0  165767.0   10.0          NaN      NaN     132.0            1.0
# 1  167609.0  167609.0    4.0          NaN      NaN     111.0            1.0
# 2  530767.0  530767.0  954.0          NaN  25345.0      19.0            1.0
# 3  530775.0  530775.0  962.0          NaN  25535.0      72.0            6.0
# 4  167601.0  167601.0   26.0          NaN      NaN     248.0            2.0
#
#    state  district  rural  ...   householdstatus  isheadchanged          fidh  \
# 0    5.0       9.0    1.0  ...               NaN            NaN           NaN
# 1    5.0       2.0    1.0  ...               1.0            2.0  5.022170e+13
# 2    5.0       1.0    2.0  ...               NaN            NaN           NaN
# 3    5.0       1.0    2.0  ...               NaN            NaN           NaN
# 4    5.0       2.0    1.0  ...               1.0            2.0  5.022160e+13
#
# ...

# %%
data2.describe()
# Out:
#                   id           id.1          m_id   client_m_id  \
# count   53503.000000   53503.000000  52980.000000  14430.000000
# mean   466141.962675  466141.962675   1692.079917    315.336729
# std    167219.824495  167219.824495   1966.785399    125.504033
# min     92539.000000   92539.000000      1.000000    133.000000
# 25%    532365.500000  532365.500000    186.000000    213.000000
# 50%    545741.000000  545741.000000    926.500000    294.000000
# 75%    559116.500000  559116.500000   2464.250000    398.000000
# max    572492.000000  572492.000000   8495.000000    713.000000
#
#                hl_id     house_no  house_hold_no    state      district  \
# count   32607.000000  53503.00000   53503.000000  53503.0  53503.000000
# mean    43529.199344    143.84113       1.196456      5.0      6.060127
# std     42583.479592    143.36479       0.675100      0.0      3.096294
# min         3.000000      1.00000       0.000000      5.0      1.000000
# ...

# %%
data2.columns
# Out:
# Index(['id', 'id.1', 'm_id', 'client_m_id', 'hl_id', 'house_no',
#        'house_hold_no', 'state', 'district', 'rural',
#        ...
#        'householdstatus', 'isheadchanged', 'fidh', 'fidx', 'as', 'wt', 'x',
#        'schedule_id', 'year', 'v126'],
#       dtype='object', length=123)

# %%
data2.dtypes
# Out:
# id                                  float64
# id.1                                float64
# m_id                                float64
# client_m_id                         float64
# hl_id                               float64
# house_no                            float64
# house_hold_no                       float64
# state                               float64
# district                            float64
# rural                               float64
# stratum_code                        float64
# psu_id                              float64
# m_serial_no                         float64
# deceased_sex                        float64
# date_of_death                       float64
# month_of_death                      float64
# year_of_death                       float64
# age_of_death_below_one_month        float64
# age_of_death_below_eleven_month     float64
# age_of_death_above_one_year         float64
# treatment_source                    float64
# ...

# %%
data2.corr()
# Out:
#                                         id      id.1      m_id  client_m_id  \
# id                                1.000000  1.000000  0.326445    -0.000138
# id.1                              1.000000  1.000000  0.326445    -0.000138
# m_id                              0.326445  0.326445  1.000000     0.189151
# client_m_id                      -0.000138 -0.000138  0.189151     1.000000
# hl_id                             0.393964  0.393964  0.956697     0.210812
# house_no                         -0.024352 -0.024352 -0.017531     0.110282
# house_hold_no                    -0.044777 -0.044777 -0.012257     0.027181
# state                                  NaN       NaN       NaN          NaN
# district                          0.007593  0.007593 -0.139518    -0.377871
# rural                            -0.012959 -0.012959  0.126708    -0.133086
# stratum_code                      0.003190  0.003190 -0.153981     0.028601
# ...

# %%
data2.cov()
# Out:
#                                             id          id.1          m_id  \
# id                                2.796247e+10  2.796247e+10  1.061161e+08
# id.1                              2.796247e+10  2.796247e+10  1.061161e+08
# m_id                              1.061161e+08  1.061161e+08  3.868245e+06
# client_m_id                      -7.216609e+01 -7.216609e+01  6.122568e+04
# hl_id                             1.579154e+08  1.579154e+08  8.534859e+07
# house_no                         -5.838117e+05 -5.838117e+05 -4.937988e+03
# house_hold_no                    -5.054866e+03 -5.054866e+03 -1.625374e+01
# state                             0.000000e+00  0.000000e+00  0.000000e+00
# district                          3.931558e+03  3.931558e+03 -8.490715e+02
# rural                            -8.199679e+02 -8.199679e+02  9.439091e+01
# stratum_code                      3.075744e+02  3.075744e+02 -1.744741e+02
# ...

# %%
data2.isnull().sum()
# Out:
# id                                      1
# id.1                                    1
# m_id                                  524
# client_m_id                         39074
# hl_id                               20897
# house_no                                1
# house_hold_no                           1
# state                                   1
# district                                1
# rural                                   1
# stratum_code                            1
# psu_id                                  1
# m_serial_no                            14
# deceased_sex                            1
# date_of_death                         139
# month_of_death                         35
# year_of_death                           1
# age_of_death_below_one_month        23144
# age_of_death_below_eleven_month     23761
# age_of_death_above_one_year          2008
# treatment_source                      327
# place_of_death                        235
# ...

# %%
df1=pd.DataFrame(data2)
cols=['id', 'id.1', 'm_id', 'client_m_id', 'hl_id', 'house_no',
       'house_hold_no', 'state', 'district', 'rural','stratum_code','psu_id', 'm_serial_no',                            
'deceased_sex',                            
'date_of_death',                         
'month_of_death',                         
'year_of_death',                           
'age_of_death_below_one_month',        
'age_of_death_below_eleven_month',     
'age_of_death_above_one_year',          
'treatment_source',                      
'place_of_death',                        
'is_death_reg',                          
'is_death_certificate_received',        
'serial_num_of_infant_mother',         
'order_of_birth',                     
'death_symptoms',                      
'is_death_associated_with_pregnan',     
'death_period',                        
'months_of_pregnancy',                   
'is_computer',                          
'is_telephone',                         
'is_washing_machine',                   
'is_refrigerator',                      
'is_sewing_machine',                    
'is_bicycle',                           
'is_scooter',                           
'is_car',                               
'is_tractor',                           
'is_water_pump','currently_dead_or_out_migrated','hh_serial_no','sex','usual_residance','relation_to_head','member_identity','father_serial_no','mother_serial_no','date_of_birth','month_of_birth','year_of_birth','age','religion','social_group_code',                        
'cart',                                 
'land_possessed',                       
'hl_expall_status',                                                      
'isdeadmigrated','residancial_status', 'factors_contributing_death',
'factors_contributing_death','factors_contributing_death_2','symptoms_of_death','time_between_onset_of_complicati','nearest_medical_facility','m_expall_status','field38','hh_id','client_hh_id',                
'iscoveredbyhealthscheme',             
'healthscheme_1',                      
'healthscheme_2','housestatus',                     
'householdstatus', 'isheadchanged', 'as', 'wt', 'x',
 'schedule_id', 'year', 'v126']
df1[cols] = df1[cols].fillna(df1.mean().iloc[0])

# %%
df1.isnull().sum()
# Out:
# id                                      0
# id.1                                    0
# m_id                                    0
# client_m_id                             0
# hl_id                                   0
# house_no                                0
# house_hold_no                           0
# state                                   0
# district                                0
# rural                                   0
# stratum_code                            0
# psu_id                                  0
# m_serial_no                             0
# deceased_sex                            0
# date_of_death                           0
# month_of_death                          0
# year_of_death                           0
# age_of_death_below_one_month            0
# age_of_death_below_eleven_month         0
# age_of_death_above_one_year             0
# treatment_source                        0
# place_of_death                          0
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['is_water_pump'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['schedule_id'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['months_of_pregnancy'].hist(bins=10)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
data2['iscoveredbyhealthscheme'].hist(bins=10)

# %%
_=plt.scatter(df1['months_of_pregnancy'], df1['iscoveredbyhealthscheme'],  color='red')
_=plt.title('months_of_pregnancy vs iscoveredbyhealthscheme')
_=plt.xlabel('months_of_pregnancy')
_=plt.ylabel('iscoveredbyhealthscheme')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
_=plt.scatter(df1['age'], df1['sex'],  color='red')
_=plt.title('age vs sex')
_=plt.xlabel('age')
_=plt.ylabel('sex')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
df1.boxplot(column='age')

# %%
df1.boxplot(column='iscoveredbyhealthscheme')

# %%
df1.boxplot(column='year_of_death')

# %%
df1.boxplot(column='age_of_death_above_one_year')

# %%
_=plt.scatter(df1['month_of_death'], df1['iscoveredbyhealthscheme'],  color='red')
_=plt.title('month_of_death vs iscoveredbyhealthscheme')
_=plt.xlabel('month_of_death')
_=plt.ylabel('iscoveredbyhealthscheme')
_=plt.xticks(())
_=plt.yticks(())
plt.show()

# %%
import seaborn as sns
sns.pairplot(df1)
